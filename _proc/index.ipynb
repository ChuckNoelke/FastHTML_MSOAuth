# %% [raw]
# ---
# description: Implementation of Oauth2.0 for AzureAD/EntraID in FastHTML
# output-file: index.html
# title: FastHTML_MSOAuth
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install FastHTML_MSOAuth in Development mode

# %% [markdown]
# ```sh
# # make sure FastHTML_MSOAuth package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to FastHTML_MSOAuth
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ChuckNoelke/FastHTML_MSOAuth.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ChuckNoelke FastHTML_MSOAuth
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install FastHTML_MSOAuth
# ```
#
#
# [repo]: https://github.com/ChuckNoelke/FastHTML_MSOAuth
# [docs]: https://ChuckNoelke.github.io/FastHTML_MSOAuth/
# [pypi]: https://pypi.org/project/FastHTML_MSOAuth/
# [conda]: https://anaconda.org/ChuckNoelke/FastHTML_MSOAuth

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ChuckNoelke/FastHTML_MSOAuth
# [docs]: https://ChuckNoelke.github.io/FastHTML_MSOAuth/
# [pypi]: https://pypi.org/project/FastHTML_MSOAuth/
# [conda]: https://anaconda.org/ChuckNoelke/FastHTML_MSOAuth

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
